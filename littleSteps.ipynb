# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import numpy.random as rnd
import bokeh.charts as bc
import bokeh.plotting as bp
from bokeh.palettes import Spectral11, Blues9

# %%
import bokeh as bk
bk.io.output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ba228325-12f4-4b5a-9bf8-adf0552d55ac">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ## Logistic Regression, Softmax and Gradient Descent

# %% [markdown]
# ### Generate some 2D data to work with

# %%
import data_gen as gen
gm = gen.GaussianMixture(n_class=2)

# %% [markdown]
# ### Frequentist Logistic regression:
#
# #### The model:
# $$Y|X \sim \text{Bernolli}( \frac{1}{1+e^{-wX}})$$
#
# #### MLE:
# * log-likelihood:
#
# \[
# \begin{align*}
#     &\log{P(Y_1, Y_2, \ldots, Y_n\mid X_1, X_2, \ldots, X_n, w)}    \\
#     =& \log{\prod_{i=1}^{n} {P(Y_i \mid X_i, w)}} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i \mid X_i, w)}} \\
#     & \text{(Assume \( Y_i\) is bernolli distrubuted with \( p=\frac{1}{1+e^{-wX}}\) )} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i=1 \mid X_i, w)^{I_{Y_i=1}}P(Y_i=0 \mid X_i, w)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{\log{p^{I_{Y_i=1}}(1-p)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{{I_{Y_i=1}}\log{p} +{I_{Y_i=0}}\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{p} + (1-Y_i)\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{\frac{p}{1-p}} + \log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i + \log{\frac{e^{-wX_i}}{1+e^{-wX_i}}}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}} \\
# \end{align*}
# \]
#
# * Maximize log-likelihood by gradient descent(ascent):
# Gradient:
#
# \[
# \begin{align*}
#     & \nabla_w{(\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}})} \\
#     =& \sum_{i=1}^{n} Y_iX_i - X_i + \frac{X_ie^{-wX_i}}{1+e^{-wX_i}}\\
# %    =& \sum_{i=1}^{n} Y_iX_i - X_i\frac{1}{1+e^{-wX_i}}\\
#     & \text{(Let}\hat{Y}_i = \frac{1}{1+e^{-wX_i}}) \\
#     =& \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i\\
# \end{align*}
# \]
#
# Find the maximum by:
#
# $$
#     w_{t+1} = w_{t} + \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i
# $$

# %%
def logistic(_x, _w):  
    # _x : numpy 2DArray
    # _w : numpy 1DArray
    # _w.size = _x.shape[1]
    return 1/(1 + np.exp(-_x.dot(_w)))

max_iter = 1000
min_err_change = 0.0001

add_offset = lambda X: np.hstack((X, np.ones((X.shape[0], 1))))
X_with_offset = add_offset(gm.tr.X)

def regress(_x, _w):
    return logistic(add_offset(_x), _w)

w = rnd.uniform(-1, 1, X_with_offset.shape[1])

lr = 0.1  # Learning rate
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking

def log_likelihood(_X, _Y, _w):
    wX = _X.dot(_w)
    return (_Y - 1).dot(wX) - np.sum(np.logaddexp(0, -wX))
    
def log_likelihood2(_Y, _Yhat):
    _p = (1 - _Y)*(1 - _Yhat) + _Y*_Yhat
    return np.sum(np.log(_p))

err0 = None

for _ in range(max_iter):
    pred_lbs = logistic(X_with_offset, w)
    diff_lb = gm.tr.y - pred_lbs
    err = np.sum(np.abs(diff_lb))
    
    _lll = log_likelihood(X_with_offset, gm.tr.y, w)
    _lll2 = log_likelihood2(gm.tr.y, pred_lbs)
    # print((lr, err, _lll, _lll2, w))
    if err0:
        if abs(err - err0) < min_err_change:
            print(_)
            break
    err0 = err
    grad = diff_lb.dot(X_with_offset)
    lr = 0.1  # Learning rate
    while log_likelihood(X_with_offset, gm.tr.y, w+lr*grad) < _lll + lr*alpha*grad.dot(grad):
        lr *= beta
    w += lr*grad

# %%
gen.visualize_2D(gm.Classes, classifyF=lambda x: regress(x, w), res=80)
# Out:
#     <div class="plotdiv" id="1b65964d-e98d-44f1-9fb8-98fda369bfda"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1b65964d-e98d-44f1-9fb8-98fda369bfda");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1b65964d-e98d-44f1-9fb8-98fda369bfda' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"57920ab8-841b-43b1-9ac3-8e4c0bf32d8f":{"roots":{"references":[{"attributes":{"callback":null,"end":6.879040777966326,"start":-8.900484576382443},"id":"9e26f7b6-bce0-4d1d-871d-0975434048f5","type":"Range1d"},{"attributes":{"below":[{"id":"656d1ab5-c8d4-492f-911b-b449033b6c94","type":"LinearAxis"}],"left":[{"id":"b22476a2-a3b7-4c28-b6bd-6ac953f443de","type":"LinearAxis"}],"renderers":[{"id":"656d1ab5-c8d4-492f-911b-b449033b6c94","type":"LinearAxis"},{"id":"00e486f0-a64c-494b-968c-82ac8fafc93c","type":"Grid"},{"id":"b22476a2-a3b7-4c28-b6bd-6ac953f443de","type":"LinearAxis"},{"id":"feeba637-d3e8-40bf-8e75-b400342c24a4","type":"Grid"},{"id":"97f865da-d6cc-42a6-8b43-1cc15cb26f3a","type":"BoxAnnotation"},{"id":"e02dd276-a301-4cf4-9c77-13f810b0b5db","type":"GlyphRenderer"},{"id":"5f0205e6-246a-4a58-8367-c18d27ccc7fb","type":"GlyphRenderer"},{"id":"e2895086-0093-4eb4-86b7-913864c61bff","type":"GlyphRenderer"}],"tool_events":{"id":"5b754b43-ab9b-47e6-a66d-3557e0e4babf","type":"ToolEvents"},"tools":[{"id":"25b543ec-5be3-48b8-a218-ed030146dbab","type":"PanTool"},{"id":"453ac91c-e494-46a8-a72e-217b68cc8a7d","type":"WheelZoomTool"},{"id":"be37a8e6-56b4-4e4b-a71e-b862e32953b5","type":"BoxZoomTool"},{"id":"ea3364c3-8cc1-477b-a9d9-a929f615ec10","type":"PreviewSaveTool"},{"id":"894f2ba8-2571-4aad-a363-d3ab639f60a9","type":"ResizeTool"},{"id":"c8971b3b-9a0d-41ca-b1dc-b23f76c55d53","type":"ResetTool"},{"id":"8a31462c-59f5-4772-bd5f-e963856af04a","type":"HelpTool"}],"x_range":{"id":"b62d1f82-faa0-4e92-9c91-12300455772f","type":"Range1d"},"y_range":{"id":"9e26f7b6-bce0-4d1d-871d-0975434048f5","type":"Range1d"}},"id":"89a3906f-3a41-418a-a125-9ecacef63281","subtype":"Figure","type":"Plot"},{"attributes":{"data_source":{"id":"271aa0a2-eadd-454a-8c58-746b40098d89","type":"ColumnDataSource"},"glyph":{"id":"a60764f8-ce67-4d89-bfda-19e34c6c8d9a","type":"Image"},"hover_glyph":null,"nonselection_glyph":{"id":"34829960-9ffb-4060-8f4e-6d4b0974f640","type":"Image"},"selection_glyph":null},"id":"e02dd276-a301-4cf4-9c77-13f810b0b5db","type":"GlyphRenderer"},{"attributes":{"palette":["#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff"]},"id":"21684c4e-c747-41d6-9f90-9083acba7959","type":"LinearColorMapper"},{"attributes":{"palette":["#969696","#bdbdbd","#d9d9d9","#f0f0f0","#ffffff"]},"id":"13f121ec-aec6-4854-be8c-4ecb687ed742","type":"LinearColorMapper"},{"attributes":{"callback":null,"column_names":["dh","x","dw","y","image"],"data":{"dh":[15.779525354348769],"dw":[11.238801502755479],"image":[[[0.9999999997833557,0.9999999996943829,0.9999999995688706,0.9999999993918121,0.9999999991420381,0.9999999987896855,0.9999999982926269,0.9999999975914335,0.9999999966022701,0.9999999952068719,0.999999993238404,0.9999999904615148,0.9999999865441975,0.9999999810180952,0.9999999732225027,0.9999999622253742,0.999999946711885,0.9999999248272321,0.9999998939548717,0.9999998504036851,0.9999997889666649,0.9999997022983662,0.9999995800366824,0.9999994075639519,0.9999991642592782,0.9999988210331117,0.9999983368493462,0.9999976538191405,0.9999966902799403,0.9999953310323481,0.999993413567802,0.9999907086409311,0.9999868928647782,0.9999815100543173,0.9999739167003467,0.9999632050623147,0.9999480947003813,0.999926779508828,0.9998967120229184,0.9998542993319492,0.9997944744826529,0.9997100926089596,0.9995910805420338,0.9994232401216775,0.9991865658955107,0.9988528835399976,0.9983825414686092,0.9977197894192216,0.9967863494858008,0.9954725252727415,0.9936250106376359,0.9910303786390039,0.9873931253315018,0.9823072684954404,0.975221167398451,0.9653969917009696,0.9518700119547286,0.9334197691234288,0.9085760884841472,0.8756967643682311,0.8331641250673876,0.7797387132772018,0.71505609070386,0.6401448527535355,0.5577208109252523,0.47198971461762007,0.38787953081034354,0.30995920228064094,0.24151603770440389,0.18415275860549604,0.1379362923769071,0.10187039822314385,0.07442049105735929,0.05392312277447607,0.03883440284172534,0.0278435360485849,0.01989889255944418,0 ...

# %% [markdown]
# ### Multi-class Logistic Regression
#
# * Assumption:
#
# $$
# Y|X = \text{Categorical}(p_1, \ldots, p_n = \frac{e^{w_n X}}{\sum_{k=1}^{n}{e^{w_k X}} })
# $$
#
# * Log likelihood:
#
# \[
# \begin{align*}
#     =& \log{\prod_{i=1}^{n} {P(Y_i \mid X_i, w_1, \ldots, w_n)}} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i \mid X_i, w_1, \ldots, w_n)}} \\
#     & (\text{Assume \( Y_i \) is catigorical distrubuted with } p_1, \ldots, p_n) \\
#     =& \sum_{i=1}^{n}{\log{\prod_{k=1}^{n}{P(Y_i=1 \mid X_i, w_k)^{I_{Y_i=k}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {\log{p_k^{I_{Y_i=k}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {I_{Y_i=k}\log{p_k}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {Y_i\log{\frac{e^{w_n X_i}}{\sum_{k=1}^{n}{e^{w_k X_i}}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {Y_i(w_k X_i - \log{\sum_{k=1}^{n}{e^{w_k X_i}}})}} \\
# \end{align*}
# \]
#
# * Gradient of log likelihood
#
# \[
# \begin{align*}
#     &\nabla_W{\sum_{i=1}^{n}{\sum_{k=1}^n {Y_i(w_k X_i - \log{\sum_{k=1}^{n}{e^{w_k X_i}}})}}}\\
#     =& \sum_{i=1}^{n}{Y_i X_i + \hat{Y}_i X_i} \\
#     &(\text{where } \hat{Y}_i = \frac{e^{w_n X_i}}{\sum_{k=1}^{n}{e^{w_k X_i}}})
# \end{align*}
# \]

# %%
gm3 = gen.GaussianMixture(n_class=3)

# %%
def softmax(_x, _W):  
    # _x : numpy 2DArray
    # _w : numpy 1DArray
    # _w.size = _x.shape[1]
    
    return 1/np.sum(np.exp(_x.dot(_W)))

max_iter = 100
min_err_change = 0.0001

lr = 1  # Learning rate
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking
w0 = None

w = rnd.uniform(-1, 1, x_dim)

def log_likelihood(_X, _Y, _w):
    wX = _X.dot(w)
    return (_Y - 1).dot(wX) - np.sum(np.logaddexp(0, -wX))
    
err0 = None
for _ in range(max_iter):
    pred_lbs = logistic(tr_fts, w)
    diff_lb = tr_lbs - pred_lbs
    err = np.sum(np.abs(diff_lb))
    
    _lll = log_likelihood(tr_fts, tr_lbs, w)
    print((err, _lll, w))
    if err0:
        if abs(err - err0) < min_err_change:
            print(_)
            break
    err0 = err
    grad = diff_lb.dot(tr_fts)
    while log_likelihood(tr_fts, tr_lbs, w+lr*grad) > _lll + lr*alpha*grad.dot(grad):
        lr *= beta
    w += lr*grad

def regress(_x):
    return logistic(_x, w)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1afabf96d0a7> in <module>()
#      14 w0 = None
#      15
# ---> 16 w = rnd.uniform(-1, 1, x_dim)
#      17
#      18 def log_likelihood(_X, _Y, _w):
#
# NameError: name 'x_dim' is not defined
