# %% [markdown]
# ## How to do math in Tensorflow (with logistic regression example)
#
# [Tensorflow](https://www.tensorflow.org/) is a framework introduced by Google for machine learning, but most people perceive it a tool for building deep neural networks. But actually it can be used as a good mathematics symbolic framework for numeric calculation and making use of the computational power of GPUs and distributed clusters effortlessly.
#
# Here I will present the classic example of logistic regression without using the built-in optimization tools.

# %% [markdown]
# ### Generate simulated data

# %%
import numpy as np
import toy_data
import bokeh.io
bokeh.io.output_notebook()

x_dim = 2
gm = toy_data.GaussianMixture(n_class=2, dim=x_dim)
toy_data.visualize_2D(gm.Classes, gm.class_colors)

data_X = gm.tr.X
data_y = np.array([gm.tr.y[:, 0]]).T
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="39104a06-5b8c-41bf-ad34-2535890a08eb">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="2f07776f-ba06-4b4c-b49c-75684dd33ebc"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2f07776f-ba06-4b4c-b49c-75684dd33ebc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2f07776f-ba06-4b4c-b49c-75684dd33ebc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d2b98a34-b717-4cd3-8705-c1cca8f755f3":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#7C78BF"},"line_color":{"value":"#7C78BF"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc347349-6d84-4296-a8cb-807c7a39fe08","type":"Circle"},{"attributes":{"plot":{"id":"b5a9261e-88f1-4ad8-8d5a-c555eabed6df","subtype":"Figure","type":"Plot"}},"id":"fe824a8a-925a-49ef-bbb4-b2070589804e","type":"PreviewSaveTool"},{"attributes":{"plot":{"id":"b5a9261e-88f1-4ad8-8d5a-c555eabed6df","subtype":"Figure","type":"Plot"}},"id":"db22af38-6779-4d39-8f7a-9b738a11717b","type":"HelpTool"},{"attributes":{},"id":"6d196182-ac93-4b72-91d5-a15f4462b5f4","type":"BasicTicker"},{"attributes":{"plot":{"id":"b5a9261e-88f1-4ad8-8d5a-c555eabed6df","subtype":"Figure","type":"Plot"}},"id":"f702c4cb-6348-44b8-b3ec-9d80b793735a","type":"ResizeTool"},{"attributes":{"fill_color":{"value":"#492A5E"},"line_color":{"value":"#492A5E"},"x":{"field":"x"},"y":{"field":"y"}},"id":"e72d6cc2-b915-4c29-93ea-deffbc194ded","type":"Circle"},{"attributes":{"overlay":{"id":"1c07c3f1-27ba-45cc-816b-07708dbde71f","type":"BoxAnnotation"},"plot":{"id":"b5a9261e-88f1-4ad8-8d5a-c555eabed6df","subtype":"Figure","type":"Plot"}},"id":"139f5df8-e562-435b-8e25-c3acda5637f0","type":"BoxZoomTool"},{"attributes":{"formatter":{"id":"3bfd1c6b-fea5-445e-aa24-0dd41718d829","type":"BasicTickFormatter"},"plot":{"id":"b5a9261e-88f1-4ad8-8d5a-c555eabed6df","subtype":"Figure","type":"Plot"},"ticker":{"id":"786d2739-ef7b-487e-93c4-8bdc242d467f","type":"BasicTicker"}},"id":"0318c908-1b05-41cd-a20b-e8d37c1c4d83","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[9.30113337384123,8.02359853653037,2.130071337236143,7.962058940763492,5.096903648215706,5.701569830902679,5.291106748727831,5.767686054342457,5.963224593975225,6.2172254626987975,4.252124471695771,6.603233267064798,5.03200772527908,5.098721299379086,6.451743711917531,6.203273426949685,3.0633532370721395,6.5617088387514055,4.509778140941459,5.955694606776255,6.89301970606307,8.687616637834552,6.615267725613222,6.271553156600521,5.8678858338096775,3.725649919808189,7.5545379444955305,8.720352391725413,6.179940893936123,5.873507876875698,7.333797761261674,5.4351999939281,4.029436427811866,6.027467227807117,5.867926857179988,4.941917557513058,6.504998463716785,6.7745153699550125,6.290571266892087,7.195974857924732,7.197389572282413,5.64331339791735,5.674223634126984,8.409679202679698,3.6209092838085577,5.63982953240186,6.927547021513328,4.278962519528882,4.332341799750098,5.517521517620829,7.778154651096973,4.51445239276519,5.906485638266483,4.659054121236655,5.067881409141142,6.247028802385481,7.131476405117137,4.034002849389803,7.548090339996476,6.5273554212518885,5.253488633063144,6.747165147774918,9.519894942223301,4.7692518658729615,7.04139295467524,5.179059947720383,6.843010946034444,5.253310003431692,5.299177542242461,8.172430665077444,7.0830935589675414,5.026681222124526,5.7443817384940825,4.371668306575968,6.3794398699105175,4.5786512556074745,7.5449241305869394,5.914954322710604,8.527269480359777,7.2324677389314935,7.29168718294233,6.570116108052266,6.259971286063654,6.873526636360683,4.876142022727131,5.484284942871342,5.176941568733826,4.445319579693136,9.952520294257372,7.810794730019335,6.35673191308041,4.482498124517413,9.265522852435609,7.067941353085379,6.4377227928571985,6.028282983562238,6.89392193797042,6.903319171642735,7.961805717707409,8.852586600480102],"y":[7.041382224848661,4.751103423533967,3.441369346964495,6.076376441157644,11.155534286166485,7.3703895389450835,4.52487532896563,7.103283234678218,4.182264978396169,9.822232587951262,5.776887714358961,8.722032076875307,14.81590645999543,5.397576375401686,6.5274527603918,5.959667349173204,5.51344211166552,7.587107041233556,5.006842394186823,6.298492644346211,7.4327446561165935,5.017359690898095,5.546555066007462,5.879383177375862,8.606069618919424,4.301798010152872,8.373712431067755,6.19314168731875,7.36548 ...

# %% [markdown]
# ### Build tensorflow graph
#
# #### Initialization:
#
# In tensorflow the input data are usually ```tf.placeholder```s and the internal variables are ```tf.Variable```s. We create a short cut for initialzation first:

# %%
import tensorflow as tf

io_tf = lambda dim: tf.placeholder(tf.float32, dim)
var_tf = lambda dim: tf.Variable(dim)

# %% [markdown]
# #### Define the logistic regression model functions
#
# (the ```/gpu:0``` forces the computation on GPU0)

# %%
def tf_logistic(_X):  
    return 1/(1 + tf.exp(-_X))

with tf.device('/gpu:0'):
    x = io_tf([None, x_dim])
    y = io_tf([None, 1])
    W = var_tf(tf.zeros([x_dim, 1]))
    b = var_tf(tf.zeros([1]))
    y_ = tf_logistic(tf.matmul(x, W) + b)
    loglikelihood = tf.reduce_sum(tf.log((1-y_)*(1-y) + y*y_))

# %% [markdown]
# #### Define the update function
# $ \frac{dy}{db} $ and $ \frac{dy}{dW} $ can be calculated automaticly by tensorflow and stored as ```dydW``` and ```dydb``` in the last two lines.
#
# we group the update steps in ```gradient_ascend```, once we run the ```gradient_ascend``` operation, the variables will be updated.

# %%
lr = 0.001  # Learning rate
with tf.device('/gpu:0'):
    dydW = tf.gradients(loglikelihood, W)[0]
    dydb = tf.gradients(loglikelihood, b)[0]
    gradient_ascend = tf.group(
        W.assign_add(lr*dydW),
        b.assign_add(lr*dydb))

# %% [markdown]
# #### Fill in data and run the tensorflow graph
#
# The script will stop if the improvement is less than ```err_min``` or the iteration is larger than ```max_iter```.

# %%
err_min = 0.01
max_iter = 1000
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.initialize_all_variables())
    
    def classifier(_X):
        _y = sess.run(y_, feed_dict={x: _X})
        _Y = np.column_stack((_y, 1 - _y))
        return _Y
    
    for i in range(max_iter):
        lll_old = sess.run(loglikelihood, {x:data_X, y:data_y})
        sess.run(gradient_ascend, {x:data_X, y:data_y})
        lll = sess.run(loglikelihood, {x:data_X, y:data_y})
        if abs(lll - lll_old) < err_min:
            break
            
    print("Optimization finished in ", i, " iterations.")

    toy_data.visualize_2D(gm.Classes, gm.class_colors, classifyF=classifier, res=100)
# Out:
# Optimization finished in  60  iterations.
#     <div class="plotdiv" id="58c93cbe-89c0-4a9a-8f35-816ab4768860"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("58c93cbe-89c0-4a9a-8f35-816ab4768860");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '58c93cbe-89c0-4a9a-8f35-816ab4768860' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b919d505-320d-4a46-be16-a621a6532f8f":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#7C78BF"},"line_color":{"value":"#7C78BF"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc347349-6d84-4296-a8cb-807c7a39fe08","type":"Circle"},{"attributes":{"callback":null,"column_names":["dh","dw","y","x","image"],"data":{"dh":[17.48209667498955],"dw":[14.477132259366332],"image":[[[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,125482 ...

# %% [markdown]
# #### Add backtracking line search to update the learning rate

# %%
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking
with tf.device('/gpu:0'):
    norm_grad = tf.reduce_sum(dydW**2) + dydb**2
    
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.initialize_all_variables())
    for i in range(max_iter):
        lll_old = sess.run(loglikelihood, {x:data_X, y:data_y})
        while True:
            sess.run(gradient_ascend, {x:data_X, y:data_y})
            lll_new = sess.run(loglikelihood, {x:data_X, y:data_y})
            norm_grad_val = sess.run(norm_grad, {x:data_X, y:data_y})
            if lll_new < lll_old + lr*alpha*norm_grad_val:
                lr *= beta
                print(lr)
            else:
                break
        if abs(lll_new - lll_old) < err_min:
            break
        
    print("Optimization finished in ", i, " iterations.")
    
    def classifier(_X):
        _y = sess.run(y_, feed_dict={x: _X})
        _Y = np.column_stack((_y, 1 - _y))
        return _Y

    toy_data.visualize_2D(gm.Classes, gm.class_colors, classifyF=classifier, res=100)
# Out:
# 0.0008
# 0.00064
# 0.0005120000000000001
# 0.0004096000000000001
# 0.0003276800000000001
# 0.0002621440000000001
# Optimization finished in  54  iterations.
#     <div class="plotdiv" id="bc12b0d2-9764-43a8-9b76-f2fdd9c9ae1f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bc12b0d2-9764-43a8-9b76-f2fdd9c9ae1f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bc12b0d2-9764-43a8-9b76-f2fdd9c9ae1f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d4c7bea-e1ab-462d-8a54-791f3c4947a9":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#7C78BF"},"line_color":{"value":"#7C78BF"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fc347349-6d84-4296-a8cb-807c7a39fe08","type":"Circle"},{"attributes":{"callback":null,"column_names":["dh","dw","y","x","image"],"data":{"dh":[17.48209667498955],"dw":[14.477132259366332],"image":[[[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220],[12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,12548220,125482 ...
