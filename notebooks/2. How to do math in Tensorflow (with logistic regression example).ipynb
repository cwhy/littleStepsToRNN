# %% [markdown]
# ## How to do math in Tensorflow (with logistic regression example)
#
# From now on the notebooks will be based on Tensorflow framework
#
# [Tensorflow](https://www.tensorflow.org/) is a framework introduced by Google for machine learning, but most people perceive it a tool for building deep neural networks. But actually it can be used as a good mathematics symbolic framework for numeric calculation and making use of the computational power of GPUs and distributed clusters effortlessly.
#
# Here I will present the classic example of logistic regression without using the built-in optimization tools.

# %% [markdown]
# ### Generate simulated data

# %%
import numpy as np
import toy_data.gaussian_mixtures as gmg
import bokeh.io
bokeh.io.output_notebook()

x_dim = 2
gm = gmg.GaussianMixture(n_class=2, dim=x_dim)
gmg.visualize_2D(gm.Classes, gm.class_colors)

data_X = gm.tr.X
data_y = np.array([gm.tr.y[:, 0]]).T
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1a97de66-a783-4d1d-a4ce-17dcd545208e">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="16f1b47c-decf-4bd7-8c84-6c1d2e3cbfb2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("16f1b47c-decf-4bd7-8c84-6c1d2e3cbfb2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '16f1b47c-decf-4bd7-8c84-6c1d2e3cbfb2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5bb2d915-b404-490a-af34-6fc58e0f903d":{"roots":{"references":[{"attributes":{},"id":"b14c29d5-500a-46af-bdd7-4f3cde454879","type":"ToolEvents"},{"attributes":{"dimension":1,"plot":{"id":"4f424693-4bec-4556-863d-2a658458d574","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac6b750f-b2fb-4ba8-9fd9-e1823f317c5b","type":"BasicTicker"}},"id":"e58b377e-60bb-47dc-90f0-05a11406e3e5","type":"Grid"},{"attributes":{"data_source":{"id":"01fbcecf-ee76-4ebf-90ce-e97258eae140","type":"ColumnDataSource"},"glyph":{"id":"cc5b53cf-dae7-4639-97da-4f154238768b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"fea94e87-7ae8-4877-b8b2-778537edfc9a","type":"Circle"},"selection_glyph":null},"id":"6a5935f2-a58b-425a-81a7-1a5683ea3f2e","type":"GlyphRenderer"},{"attributes":{"callback":null,"end":11.53836467286851,"start":-0.39235407945815215},"id":"e941370c-0611-430a-8bb0-1b424a09e89b","type":"Range1d"},{"attributes":{},"id":"98253534-8cc7-461d-92b8-d8775a415ffa","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"98253534-8cc7-461d-92b8-d8775a415ffa","type":"BasicTickFormatter"},"plot":{"id":"4f424693-4bec-4556-863d-2a658458d574","subtype":"Figure","type":"Plot"},"ticker":{"id":"ac6b750f-b2fb-4ba8-9fd9-e1823f317c5b","type":"BasicTicker"}},"id":"cf1cecc8-211d-470c-82ef-acbb5cf972a2","type":"LinearAxis"},{"attributes":{"plot":{"id":"4f424693-4bec-4556-863d-2a658458d574","subtype":"Figure","type":"Plot"},"ticker":{"id":"0304d72b-3dec-4bdf-8799-262b06f323fd","type":"BasicTicker"}},"id":"43f9597f-2b55-4656-8c22-82d2f2983ea3","type":"Grid"},{"attributes":{},"id":"6bd79a10-313b-41ce-a5a5-09581631a6bf","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c3cc7748-7123-4c73-b32b-0f9b96eb9d5b","type":"Circle"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"1706e152-5402-484b-9cb1-58c592be36fe","type":"BoxAnnotation"},{"attributes":{"fill_color":{"value":"#3667B2"},"line_color":{"value":"#3667B2"},"x":{"field":"x"},"y":{"field":"y"}},"id":"59f64b84-944f-4edf-a433-46b28e0f8ad9","type":"Circle"},{"attributes":{"formatter":{"id":"6bd79a10-313b-41ce-a5a5-09581631a6bf","type":"BasicTickFormatter"},"plot":{"id":"4f424693-4bec-4556-863d-2a658458d574","subtype":"Figure","type":"Plot"},"ticker":{"id":"0304d72b-3dec-4bdf-8799-262b06f323fd","type":"BasicTicker"}},"id":"c8a42bac-5290-48e7-8b07-427046906ae9","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"fea94e87-7ae8-4877-b8b2-778537edfc9a","type":"Circle"},{"attributes":{"plot":null,"text":null},"id":"009da63e-658a-46a7-8ff0-19fa358af2d7","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.5161963026280869,0.5799048223906087,0.7730981115184667,2.8323099154875395,-1.0165971569823111,0.7849466304269344,-0.1685994707654132,0.0974346855604245,-0.7807372184912844,-1.2927329463245933,5.78479612031021,-0.5254701385111742,-1.350727082255232,3.137236606916574,-1.0753174683416635,1.8796499701841014,-0.11251814052464426,-0.3193305366792458,-0.22662816716633627,-1.0999974355705848,-2.8019843424506155,1.500618131149721,-0.9305094026074414,1.4967785260455928,0.20390351972729778,-0.12759267692921034,-1.6150174279720044,-0.059507924648649846,-0.6967883786568008,-1.3144284917216569,1.3487996791933745,-0.15598994074871164,-1.378844541478252,0.6019438105967433,2.2426495551445687,0.3178751802547345,0.5403251700673998,1.9682645285512586,0.9783941012786309,0.862928360119593,3.85154 ...

# %% [markdown]
# ### Build tensorflow graph
#
# #### Initialization:
#
# In tensorflow the input data are usually ```tf.placeholder```s and the internal variables are ```tf.Variable```s. We create a short cut for initialzation first:

# %%
import tensorflow as tf

io_tf = lambda dim: tf.placeholder(tf.float32, dim)
var_tf = lambda init: tf.Variable(init)

# %% [markdown]
# #### Define the logistic regression model functions
#
# (the ```/gpu:0``` forces the computation on GPU0)

# %%
def tf_logistic(_X):  
    return 1/(1 + tf.exp(-_X))

with tf.device('/gpu:0'):
    x = io_tf([None, x_dim])
    y = io_tf([None, 1])
    W = var_tf(tf.zeros([x_dim, 1]))
    b = var_tf(tf.zeros([1]))
    y_ = tf_logistic(tf.matmul(x, W) + b)
    loglikelihood = tf.reduce_sum(tf.log((1-y_)*(1-y) + y*y_))

# %% [markdown]
# #### Define the update function
# $ \frac{dy}{db} $ and $ \frac{dy}{dW} $ can be calculated automaticly by tensorflow and stored as ```dydW``` and ```dydb``` in the last two lines.
#
# we group the update steps in ```gradient_ascend```, once we run the ```gradient_ascend``` operation, the variables will be updated.

# %%
lr = 0.001  # Learning rate
with tf.device('/gpu:0'):
    dydW = tf.gradients(loglikelihood, W)[0]
    dydb = tf.gradients(loglikelihood, b)[0]
    gradient_ascend = tf.group(
        W.assign_add(lr*dydW),
        b.assign_add(lr*dydb))

# %% [markdown]
# #### Fill in data and run the tensorflow graph
#
# The script will stop if the improvement is less than ```err_min``` or the iteration is larger than ```max_iter```.

# %%
err_min = 0.01
max_iter = 1000
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.initialize_all_variables())
    
    def classifier(_X):
        _y = sess.run(y_, feed_dict={x: _X})
        _Y = np.column_stack((_y, 1 - _y))
        return _Y
    
    for i in range(max_iter):
        lll_old = sess.run(loglikelihood, {x:data_X, y:data_y})
        sess.run(gradient_ascend, {x:data_X, y:data_y})
        lll = sess.run(loglikelihood, {x:data_X, y:data_y})
        if abs(lll - lll_old) < err_min:
            break
            
    print("Optimization finished in ", i, " iterations.")

    gmg.visualize_2D(gm.Classes, gm.class_colors, classifyF=classifier, res=100)
# Out:
# Optimization finished in  100  iterations.
#     <div class="bk-root">
#         <div class="plotdiv" id="508e2753-b96e-4b41-84d2-aecde6d6084c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("508e2753-b96e-4b41-84d2-aecde6d6084c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '508e2753-b96e-4b41-84d2-aecde6d6084c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"db0f846c-30fc-4e74-b8d6-cd3d2d76df4e":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"eb422bf8-2c76-4c13-b81f-b71cffa1f443","type":"Circle"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"ed6883ea-deec-404b-972d-52a399aef378","type":"ImageRGBA"},{"attributes":{"data_source":{"id":"1e1679b9-5711-4157-a443-e66b227bd468","type":"ColumnDataSource"},"glyph":{"id":"d65a33d5-2c2e-499f-af06-429e2bb6f6af","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"5a28317d-9626-446d-98cf-f18d4768b660","type":"Circle"},"selection_glyph":null},"id":"b3b50232-be30-4bc6-901a-bcffc011cd66","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"892970eb-03a9-46d0-9e26-8052c2662860","subtype":"Figure","type":"Plot"}},"id":"2ed62c28-4fe1-40f7-bb4b-7c9893183597","type":"PanTool"},{"attributes":{"plot":null,"text":null},"id":"0007f394-5336-441f-85e0-389d6b7aa6f0","type":"Title"},{"attributes":{},"id":"868cefc0-e2a2-4950-8336-f6d926e0c496","type":"BasicTicker"},{"attributes":{"plot":{"id":"892970eb-03a9-46d0-9e26-8052c2662860","subtype":"Figure","type":"Plot"}},"id":"35050503-ace8-4f07-b10a-31fb1c99390b","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2ed62c28-4fe1-40f7-bb4b-7c9893183597","type":"PanTool"},{"id":"b8bbf281-978b-4065-b884-1e38be2060e0","type":"WheelZoomTool"},{"id":"faca4e6f-517d-431d-a3d2-38be719f48bf","type":"BoxZoomTool"},{"id":"301ee46f-bce5-4f70-98a1-5200d5990f73","type":"SaveTool"},{"id":"35050503-ace8-4f07-b10a-31fb1c99390b","type":"ResetTool"},{"id":"a5742214-d8b3-4f81-add0-d20854cc4150","type":"HelpTool"}]},"id":"2c1fcce0-e9b3-46cf-a3e7-b68c858d224f","type":"Toolbar"},{"attributes":{"fill_color":{"value":"#3667B2"},"line_color":{"value":"#3667B2"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d65a33d5-2c2e-499f-af06-429e2bb6f6af","type":"Circle"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"1a345b29-f79a-4001-a5cb-cdf14c601858","type":"ImageRGBA"},{"attributes":{"plot":{"id":"892970eb-03a9-46d0-9e26-8052c2662860","subtype":"Figure","type":"Plot"}},"id":"a5742214-d8b3-4f81-add0-d20854cc4150","type":"HelpTool"},{"attributes":{},"id":"fb8d1dc3-03da-410c-b8e0-4a3ac8a40769","type":"ToolEvents"},{"attributes":{"plot":{"id":"892970eb-03a9-46d0-9e26-8052c2662860","subtype":"Figure","type":"Plot"},"ticker":{"id":"b0e97e18-57b7-4007-9e12-c71c2bd24a05","type":"BasicTicker"}},"id":"96b6ad54-1f95-4c25-a1bb-92ecf308d667","type":"Grid"},{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"b865e856-f4ec-4071-9c66-8390362fd949","type":"ImageRGBA"},{"attributes":{"callback":null,"column_names":["x","dw","y","image","dh"],"data":{"dh":[11.930718752326662],"dw":[11.077018186839009],"image":[[[28469046,28469046,28469046,45246262,45246262,45246262,62023478,62023478,62023478,78800694,78800694,95577910,112355126,129132342,145909558,162686774,179463990,196241206,229795638,246572854,280127286,313681718,347236150,380790582,414345014,464676662,498231094,531785526,582117174,615671606,666003254,699557686,733112118,766666550,800220982,833775414,850552630,884107062,900884278,934438710,951215926,967993142,984770358,984770358,1001547574,1018324790,1018324790,1035102006,1035102006,1035102006,1051879222,1051879222,1051879222,1051879222,1068656438,1068656438,1068656438,1068656438,1068656438,1068656438,1068656438,1068656438,1068656438,1068656438,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433654,1085433 ...

# %% [markdown]
# #### Add backtracking line search to update the learning rate

# %%
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking
with tf.device('/gpu:0'):
    norm_grad = tf.reduce_sum(dydW**2) + dydb**2
    
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.initialize_all_variables())
    for i in range(max_iter):
        lll_old = sess.run(loglikelihood, {x:data_X, y:data_y})
        while True:
            sess.run(gradient_ascend, {x:data_X, y:data_y})
            lll_new = sess.run(loglikelihood, {x:data_X, y:data_y})
            norm_grad_val = sess.run(norm_grad, {x:data_X, y:data_y})
            if lll_new < lll_old + lr*alpha*norm_grad_val:
                lr *= beta
                print(lr)
            else:
                break
        if abs(lll_new - lll_old) < err_min:
            break
        
    print("Optimization finished in ", i, " iterations.")
    
    def classifier(_X):
        _y = sess.run(y_, feed_dict={x: _X})
        _Y = np.column_stack((_y, 1 - _y))
        return _Y

    gmg.visualize_2D(gm.Classes, gm.class_colors, classifyF=classifier, res=100)
# Out:
# Optimization finished in  100  iterations.
#     <div class="bk-root">
#         <div class="plotdiv" id="0e0ae1be-d620-489c-9fa9-06dd10a366b4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0e0ae1be-d620-489c-9fa9-06dd10a366b4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0e0ae1be-d620-489c-9fa9-06dd10a366b4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"320f7e74-54d5-497c-99e1-266460371b1f":{"roots":{"references":[{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2adf39bd-7aae-4944-81ac-124a8fe910ae","type":"ImageRGBA"},{"attributes":{"formatter":{"id":"3fafbcdd-b139-4d80-bfb2-98f113986d2e","type":"BasicTickFormatter"},"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d63ecea-594f-43e4-b9fe-f00c11578547","type":"BasicTicker"}},"id":"c5bf9797-35d8-4051-9fc5-fd0e4b8744e8","type":"LinearAxis"},{"attributes":{"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"},"ticker":{"id":"ef0f3883-ecce-42fb-8311-cc87531cc0c2","type":"BasicTicker"}},"id":"a7d50ed2-6e66-43e2-8cef-77db49c79855","type":"Grid"},{"attributes":{"callback":null,"end":11.53836467286851,"start":-0.39235407945815215},"id":"6b4b4e70-c216-48be-9e08-0435d4166f6d","type":"Range1d"},{"attributes":{"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"}},"id":"7d1ca5b7-79ef-43f3-bde3-94ba42234124","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"2da717c1-41b8-437f-a537-b62677444e29","type":"BoxAnnotation"},"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"}},"id":"aea3b2bf-e40f-491a-9d4b-71c58515ffc1","type":"BoxZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"7975ab22-6ee1-45cf-894e-57bbecd31011","type":"PanTool"},{"id":"7d1ca5b7-79ef-43f3-bde3-94ba42234124","type":"WheelZoomTool"},{"id":"aea3b2bf-e40f-491a-9d4b-71c58515ffc1","type":"BoxZoomTool"},{"id":"bb8ead2d-5b76-431a-bbd9-8184e28f055f","type":"SaveTool"},{"id":"a0327830-f56c-47ca-90c6-bba24dd54d4a","type":"ResetTool"},{"id":"c4d8d107-6764-47c6-bd51-637ef570dd58","type":"HelpTool"}]},"id":"c7033b10-8e1c-4b95-bdad-b1236183d4e7","type":"Toolbar"},{"attributes":{"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"}},"id":"7975ab22-6ee1-45cf-894e-57bbecd31011","type":"PanTool"},{"attributes":{"dimension":1,"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"},"ticker":{"id":"7d63ecea-594f-43e4-b9fe-f00c11578547","type":"BasicTicker"}},"id":"7dd98517-de90-4b20-a6e1-e076bc93580d","type":"Grid"},{"attributes":{"data_source":{"id":"124559a4-fc4c-472b-a3c0-2a2f82f4f2dc","type":"ColumnDataSource"},"glyph":{"id":"147b142b-5a5f-4a5b-b727-4d7da82410f0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"58bda27a-5615-4d89-b5cf-f5c926f9e274","type":"Circle"},"selection_glyph":null},"id":"1c9763ff-f6ba-41d4-b80a-d32884586a2f","type":"GlyphRenderer"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2da717c1-41b8-437f-a537-b62677444e29","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"ac8411e9-a42d-4fd7-a00f-caf533804227","subtype":"Figure","type":"Plot"}},"id":"bb8ead2d-5b76-431a-bbd9-8184e28f055f","type":"SaveTool"},{"attributes":{"data_source":{"id":"0aecc0e2-9427-4358-b387-f8c27d8661df","type":"ColumnDataSource"},"glyph":{"id":"2adf39bd-7aae-4944-81ac-124a8fe910ae","type":"ImageRGBA"},"hover_glyph":null,"nonselection_glyph":{"id":"ce6783a5-479d-4fad-b150-391a2e601806","type":"ImageRGBA"},"selection_glyph":null},"id":"f5576806-e642-4d7c-8e00-6dcd141003b2","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"03669b52-d01f-41b8-82f7-fdbd18780e98","type":"ColumnDataSource"},"glyph":{"id":"843817cf-083d-4478-adc1-ce0a83b0c98a","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"3c174a99-acce-4262-8daf-bbcc9e3061fb","type":"Circle"},"selection_glyph":null},"id":"7cbf9d19-8234-47 ...
