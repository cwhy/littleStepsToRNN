# %% [markdown]
# ## Logistic Regression and Gradient Descent
#
# ### The task: Binary classification
#
# #### Generate data points in 2D to work with:

# %%
import toy_data
import bokeh.io
bokeh.io.output_notebook()

gm = toy_data.GaussianMixture(n_class=2)
toy_data.visualize_2D(gm.Classes, gm.class_colors)
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0667fdbd-e069-4a24-9397-279950cbce52">Loading BokehJS ...</span>
#     </div>
#     <div class="plotdiv" id="0e60283a-c1eb-4769-8d52-39d220364b71"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("0e60283a-c1eb-4769-8d52-39d220364b71");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '0e60283a-c1eb-4769-8d52-39d220364b71' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d8c74321-4f1a-4a7b-a830-7ed000209ba7":{"roots":{"references":[{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"c13df7fa-fc4b-463e-87e9-3934ae6abab3","type":"Circle"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"a5825fe9-3627-4438-b85e-91154a67923c","type":"WheelZoomTool"},{"attributes":{"dimension":1,"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"},"ticker":{"id":"5c37123f-31c8-4669-9229-4781c2df91b4","type":"BasicTicker"}},"id":"0724c7b4-1fb2-42eb-af7a-b24407558395","type":"Grid"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"a3be7f67-6533-49d4-9b9d-d01bec3e860f","type":"ResetTool"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"6858bce0-9e83-4e71-a2f2-e572846f9670","type":"HelpTool"},{"attributes":{},"id":"75d9b184-f18d-453c-bbb3-e9b755c9a3cb","type":"BasicTicker"},{"attributes":{"callback":null,"end":9.629599617010516,"start":-4.574301998628254},"id":"25091669-6460-4589-9008-1a05712f3c06","type":"Range1d"},{"attributes":{"overlay":{"id":"37d10247-b4f1-4951-84f3-cc61f4d75392","type":"BoxAnnotation"},"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"998d747e-447f-4d2b-8079-e80c625eb694","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"#CF4A68"},"line_color":{"value":"#CF4A68"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6157c036-25fe-4b2d-a98b-6e874ecc2bde","type":"Circle"},{"attributes":{},"id":"f5bab586-a21c-480a-bf63-a902bfbef3d4","type":"ToolEvents"},{"attributes":{},"id":"5c37123f-31c8-4669-9229-4781c2df91b4","type":"BasicTicker"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"946aea96-a8c9-491a-977f-e1984be7869b","type":"ResizeTool"},{"attributes":{"callback":null,"end":7.298139995738674,"start":-5.784115590375971},"id":"9dbcb7cf-d0c6-48fc-a0d9-632a4c5522a8","type":"Range1d"},{"attributes":{"data_source":{"id":"8294ff73-6149-424d-a489-8e452469cde9","type":"ColumnDataSource"},"glyph":{"id":"1db11796-c923-4705-8f0a-903acbbe9e71","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"b9ffa343-bcfb-4d7a-8c72-ece4006e539a","type":"Circle"},"selection_glyph":null},"id":"3f2145a4-282c-4a65-8d45-53c26b30813e","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"},"ticker":{"id":"75d9b184-f18d-453c-bbb3-e9b755c9a3cb","type":"BasicTicker"}},"id":"c7006d7d-1213-46e5-867a-0ff43b04b205","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"37d10247-b4f1-4951-84f3-cc61f4d75392","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"}},"id":"a0762d95-710d-457c-b713-dc3d192eee9d","type":"PanTool"},{"attributes":{"data_source":{"id":"560dcc66-fee1-4591-9258-2a9b843403aa","type":"ColumnDataSource"},"glyph":{"id":"6157c036-25fe-4b2d-a98b-6e874ecc2bde","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"c13df7fa-fc4b-463e-87e9-3934ae6abab3","type":"Circle"},"selection_glyph":null},"id":"42200774-d872-4ad3-a095-e2dc97f2ba29","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"ee5dc34d-9f56-40e6-a5f0-e732ca2766ab","type":"BasicTickFormatter"},"plot":{"id":"e2e9280e-ea06-44c9-9f5f-f3a9b1108737","subtype":"Figure","type":"Plot"},"ticker":{"id":"75d9b184-f18d-453c-bbb3-e9b755c9a3cb","type":"BasicTicker"}},"id":"01dd ...

# %% [markdown]
# ### Logistic regression:
#
# #### The model:
# $$
# Y|X \sim \text{Bernolli}( \frac{1}{1+e^{-wX}})
# $$
# We assume the class labels are 0 and 1, and is [Bernolli distributed](https://en.wikipedia.org/wiki/Bernoulli_distribution).
# $\def\logi{\frac{1}{1+e^{-wX}}}$
# We also assume given $X$, the probability of getting a 1 is the _logistic function_ $\logi$. I will write a detailed introduction to the rationale of it later, but intuitively we can transfrom $y = \logi$ to $\log{y} + \log{1-y} = wX$, where we map the probability of getting a both answers to a linear transfromation of $X$ by $w$ using $\log$ function.

# %% [markdown]
# #### Maximun Likelihood Estimation(MLE):
#
# Given the sampled data, we can estimate linear parameter $w$ using maximumize likelihood estimation, where we find the most possible $w$ that generates the data.
#
#
# * First we find log-likelihood, which is equivalent to likelihood if we want to maximize it:
#
# $$
# \begin{align*}
#     &\log{P(Y_1, Y_2, \ldots, Y_n\mid X_1, X_2, \ldots, X_n, w)}    \\
#     =& \log{\prod_{i=1}^{n} {P(Y_i \mid X_i, w)}} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i \mid X_i, w)}} \\
#     & \text{(Assume \( Y_i\) is bernolli distrubuted with \( p=\frac{1}{1+e^{-wX}}\) )} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i=1 \mid X_i, w)^{I_{Y_i=1}}P(Y_i=0 \mid X_i, w)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{\log{p^{I_{Y_i=1}}(1-p)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{{I_{Y_i=1}}\log{p} +{I_{Y_i=0}}\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{p} + (1-Y_i)\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{\frac{p}{1-p}} + \log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i + \log{\frac{e^{-wX_i}}{1+e^{-wX_i}}}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}} \\
# \end{align*}
# $$
#
# Hence we are finding
# $$
# \max_{w}{\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}}}
# $$

# %% [markdown]
# ### Gradient Descent
#
# From MLE, we have the following optimization problem:
# $$
#    \max_{w}{\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}}}
# $$
#
# We can use gradient ascent to iteratively find the maximum, where we calculate the gradient of the likelihood in each step, and update $w$ by $ w_{t+1} = w_{t} + \nabla_w$
#
# * Calculating the Gradient:
#
# $$
# \begin{align*}
#     & \nabla_w{(\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}})} \\
#     =& \sum_{i=1}^{n} Y_iX_i - X_i + \frac{X_ie^{-wX_i}}{1+e^{-wX_i}}\\
# %    =& \sum_{i=1}^{n} Y_iX_i - X_i\frac{1}{1+e^{-wX_i}}\\
#     & \text{(Let}\hat{Y}_i = \frac{1}{1+e^{-wX_i}}) \\
#     =& \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i\\
# \end{align*}
# $$
#
# * Hence we can find the maximum by:
#
# $$
#     w_{t+1} = w_{t} + \alpha \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i
# $$
#
# , where $\alpha$ is the learning rate

# %% [markdown]
# ### Numpy implementation:
#
# We first define the logistic function and two ways to calculate the likelihood as Python functions

# %%
import numpy as np
import numpy.random as rnd

def logistic(_x, _w):  
    # _x : numpy 2DArray
    # _w : numpy 1DArray
    # _w.size = _x.shape[1]
    return 1/(1 + np.exp(-_x.dot(_w)))

def log_likelihood(_X, _Y, _w):
    wX = _X.dot(_w)
    return (_Y - 1).dot(wX) - np.sum(np.logaddexp(0, -wX))
    
def log_likelihood2(_Y, _Yhat):
    _p = (1 - _Y)*(1 - _Yhat) + _Y*_Yhat
    return np.sum(np.log(_p))

# %% [markdown]
# and we add a column of 1 to $X$ to simulate $wX + b$ by $w[X:1]$

# %%
add_offset = lambda X: np.hstack((X, np.ones((X.shape[0], 1))))
X_with_offset = add_offset(gm.tr.X)

# %% [markdown]
# * Then we implement gradient ascent on ```w```
#
# Note that we dynamically adjust the learning rate ```lr``` using [backtracking](https://en.wikipedia.org/wiki/Backtracking_line_search) with parameter ```beta``` and ```alpha```.
#
# The for loop will end if maximun iteration is reached or the error converges.

# %%
max_iter = 1000
min_err_change = 0.0001

w = rnd.uniform(-1, 1, X_with_offset.shape[1])

lr = 0.1  # Learning rate
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking


err0 = None

for _ in range(max_iter):
    pred_lbs = logistic(X_with_offset, w)
    diff_lb = gm.tr.y[:,0] - pred_lbs
    err = np.sum(np.abs(diff_lb))
    
    _lll = log_likelihood(X_with_offset, gm.tr.y[:,0], w)
    # print((lr, err, _lll, _lll2, w))
    if err0:
        if abs(err - err0) < min_err_change:
            print(_)
            break
    err0 = err
    grad = diff_lb.dot(X_with_offset)
    lr = 0.1  # Learning rate
    while log_likelihood(X_with_offset, gm.tr.y[:,0], w+lr*grad) < _lll + lr*alpha*grad.dot(grad):
        lr *= beta
    w += lr*grad
# Out:
# 150

# %% [markdown]
# #### Visualization of the classification results

# %%
def regress(_x, _w):
    _y = logistic(add_offset(_x), _w)
    _Y = np.column_stack((_y, 1 - _y))
    return _Y

toy_data.visualize_2D(gm.Classes, gm.class_colors, classifyF=lambda x: regress(x, w), res=80)
# Out:
#     <div class="plotdiv" id="132558a6-275e-41d6-90a0-549014c1d429"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById
,7.1666084909307735,6.0456983000896525,5.723991749433892,2.017553869260489,6.671098447302904,1.9711289490368165],"y":[4.244427080942298,3.947726674793835,3.308086313127234,2.818207067525755,4.846360600832005,6.923900521086445,2.3327388132950913,3.437511824624792,8.111584575480034,3.629757945160399,5.557251896705635,4.907668820580152,1.7567263782688762,7.78936030649413,1.982504392331046,8.45931674754127,2.9677289444653425,5.308709317363374,3.9515207404833372,4.878160569882067,0.4522212600364419,5.335561674483952,4.072978484308205,5.18848550733063,4.314638899249812,5.279922180045377,4.664354533619456,7.570764773859636,5.626156850352848,6.7155603778486945,3.769440632608606,7.591625477647456,-0.35845456254146324,2.6590573742896266,4.605273585159413,2.9481884546369552,6.9114381579988144,4.173377780209725,8.66730904169085,4.11568629684782,4.716 ...

# %%
import tensorflow as tf

x_dim = 2


io_tf = lambda dim: tf.placeholder(tf.float32, dim)
var_tf = lambda dim: tf.Variable(dim)
def tf_logistic(_X):  
    return 1/(1 + tf.exp(-_X))
with tf.device('/gpu:0'):
    x = io_tf([None, x_dim])
    y = io_tf([None, 1])
    W = var_tf(tf.zeros([x_dim, 1]))
    b = var_tf(tf.zeros([1]))
    y_ = tf_logistic(tf.matmul(x, W) + b)
    loglikelihood = tf.reduce_sum(tf.log((1-y_)*(1-y) + y*y_))
    dydW = tf.gradients(loglikelihood, W)
    dydb = tf.gradients(loglikelihood, b)

lr = 0.1  # Learning rate
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking
data_X = gm.tr.X
data_y = np.array([gm.tr.y[:, 0]]).T
with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    writer = tf.train.SummaryWriter('summary', sess.graph)
    sess.run(tf.initialize_all_variables())
    for i in range(50):
        l = sess.run(loglikelihood, {x:data_X, y:data_y})
        db = sess.run(dydb, {x:data_X, y:data_y})
        dw = sess.run(dydW, {x:data_X, y:data_y})

        W_old = W.eval()
        b_old = b.eval()
        while True:
            W.assign(W_old + lr*dw[0]).eval()
            b.assign(b_old + lr*db[0]).eval()
            ln = sess.run(loglikelihood, {x:data_X, y:data_y})
            norm_grad = np.sum(dw[0]**2) + db[0]**2
            if ln < l + lr*alpha*norm_grad:
                lr *= beta
            else:
                break
        
    def classifier(_X):
        _y = sess.run(y_, feed_dict={x: _X})
        _Y = np.column_stack((_y, 1 - _y))
        return _Y

    toy_data.visualize_2D(gm.Classes, gm.class_colors, classifyF=classifier, res=100)
# Out:
#     <div class="plotdiv" id="db23eb66-7742-46ed-885c-173874555269"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("db23eb66-7742-46ed-885c-173874555269");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'db23eb66-7742-46ed-885c-173874555269' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"3584e661-3b1b-4023-a456-23a61f4d7d50":{"roots":{"references":[{"attributes":{"dh":{"field":"dh","units":"data"},"dw":{"field":"dw","units":"data"},"image":{"field":"image"},"x":{"field":"x"},"y":{"field":"y"}},"id":"987ecd6d-4a99-4818-8c04-95c23af8b20c","type":"ImageRGBA"},{"attributes":{"overlay":{"id":"528a6385-307e-4fc9-bddd-52a60cb723c4","type":"BoxAnnotation"},"plot":{"id":"4357e9f0-5080-4c6f-a7dd-031b04e95106","subtype":"Figure","type":"Plot"}},"id":"15284b8d-a4ad-44ea-b18e-0305926dbdc3","type":"BoxZoomTool"},{"attributes":{"data_source":{"id":