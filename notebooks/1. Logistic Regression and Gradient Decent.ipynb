# %% [markdown]
# ## Logistic Regression and Gradient Descent
#
# ### The task: Binary classification
#
# #### Generate data points in 2D to work with:

# %%
import toy_data.gaussian_mixtures as gmg
import bokeh.io
bokeh.io.output_notebook()

gm = gmg.GaussianMixture(n_class=2)
gmg.visualize_2D(gm.Classes, gm.class_colors)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="84984bec-f4f6-4487-acda-4f013ed81b59">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="f1f41fd0-575b-45c7-a92c-052dc208ba77"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f1f41fd0-575b-45c7-a92c-052dc208ba77");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f1f41fd0-575b-45c7-a92c-052dc208ba77' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"09ea1ea4-1fcc-414f-8d77-115ff75e3744":{"roots":{"references":[{"attributes":{},"id":"4dd41aef-8548-43e9-aea0-e084e7ceaaf0","type":"BasicTickFormatter"},{"attributes":{"callback":null,"end":5.109362308647533,"start":-8.762611150481723},"id":"8838695e-666f-4e94-addc-425c419cdd0f","type":"Range1d"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"512ad77c-d3a4-4e03-9214-80ceb75e34e7","type":"BoxAnnotation"},{"attributes":{},"id":"f4e1f59a-322b-497f-9714-f644c13d2908","type":"BasicTicker"},{"attributes":{},"id":"a3852a21-dd77-4b80-9cb4-d1c866a65be4","type":"ToolEvents"},{"attributes":{"formatter":{"id":"4dd41aef-8548-43e9-aea0-e084e7ceaaf0","type":"BasicTickFormatter"},"plot":{"id":"1d82a9d2-8ab9-480e-ab0b-3ea2abb3d875","subtype":"Figure","type":"Plot"},"ticker":{"id":"f4e1f59a-322b-497f-9714-f644c13d2908","type":"BasicTicker"}},"id":"3f306bf9-855b-4ce7-a537-5d1bb6d1c909","type":"LinearAxis"},{"attributes":{"formatter":{"id":"fdbf198f-64f9-40e1-9ea2-90abc9313594","type":"BasicTickFormatter"},"plot":{"id":"1d82a9d2-8ab9-480e-ab0b-3ea2abb3d875","subtype":"Figure","type":"Plot"},"ticker":{"id":"f5a5a8c0-15a1-4d27-b761-2aa5a82d62cb","type":"BasicTicker"}},"id":"bdf08679-cd25-493c-8ed6-f7aed90ebe2a","type":"LinearAxis"},{"attributes":{"plot":{"id":"1d82a9d2-8ab9-480e-ab0b-3ea2abb3d875","subtype":"Figure","type":"Plot"}},"id":"bb5dd9c6-027a-4b22-9beb-8fc493379991","type":"WheelZoomTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e007e989-4417-4950-a4e9-ec15ca40305a","type":"PanTool"},{"id":"bb5dd9c6-027a-4b22-9beb-8fc493379991","type":"WheelZoomTool"},{"id":"dd2781d2-2b64-4d79-88c9-31385800c1d8","type":"BoxZoomTool"},{"id":"0d4a905c-7c08-4c35-8e6f-9ba2f8258268","type":"SaveTool"},{"id":"ec2fdf33-a696-4bca-a8dc-602899bfc747","type":"ResetTool"},{"id":"8f3ff144-d079-4f36-82a6-e6937d0b96b8","type":"HelpTool"}]},"id":"299bba4c-ee79-49d3-a5eb-9d2b62c3d12c","type":"Toolbar"},{"attributes":{"data_source":{"id":"737228f5-4d19-4613-900c-5a9c2e32674a","type":"ColumnDataSource"},"glyph":{"id":"21e06220-86d0-482a-a3f2-3886692fd7b8","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6cc7f289-116c-490a-806d-6cfb9efd5898","type":"Circle"},"selection_glyph":null},"id":"4f3faa19-c47c-4e9f-b15d-f788c1de3c31","type":"GlyphRenderer"},{"attributes":{},"id":"f5a5a8c0-15a1-4d27-b761-2aa5a82d62cb","type":"BasicTicker"},{"attributes":{},"id":"fdbf198f-64f9-40e1-9ea2-90abc9313594","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"#B24E36"},"line_color":{"value":"#B24E36"},"x":{"field":"x"},"y":{"field":"y"}},"id":"654e16f1-63df-4815-9af7-8331bbce6976","type":"Circle"},{"attributes":{"below":[{"id":"3f306bf9-855b-4ce7-a537-5d1bb6d1c909","type":"LinearAxis"}],"left":[{"id":"bdf08679-cd25-493c-8ed6-f7aed90ebe2a","type":"LinearAxis"}],"plot_height":500,"plot_width":500,"renderers":[{"id":"3f306bf9-855b-4ce7-a537-5d1bb6d1c909","type":"LinearAxis"},{"id":"ce5061ea-36e3-49bb-9069-b16c88fa2d8d","type":"Grid"},{"id":"bdf08679-cd25-493c-8ed6-f7aed90ebe2a","type":"LinearAxis"},{"id":"4230ef56-2f63-4dcf-b42c-30a72e66ec21","type":"Grid"},{"id":"512ad77c-d3a4-4e03-9214-80ceb75e34e7","type":"BoxAnnotation"},{"id":"a9eff39c-a159-4db5-bc7c-d96750ace5ff","type":"GlyphRenderer"},{"id":"4f3faa19-c47c-4e9f-b15d-f788c1de3c31","type":"GlyphRenderer"}],"title":{"id":"c431d24d-c733-478e-aabe-05c6ceafbc96","type":"Title"},"tool_events":{"id":"a3852a21-dd77-4b80-9cb4-d1c866a65be4","type":"ToolEvents"},"toolbar":{"id":"299bba4c-ee79-49d3-a5eb-9d2b62c3d12c","type":"Toolbar"},"x_range":{"id":"998f70dc-2daa-4ca3-93e9-72ec7ebd3d71","type":"Range1d"},"y_range":{"id":"8838695e-666f-4e94-addc-425c419cdd0f","type":" ...

# %% [markdown]
# ### Logistic regression:
#
# #### The model:
# $$
# Y|X \sim \text{Bernolli}( \frac{1}{1+e^{-wX}})
# $$
# We assume the class labels are 0 and 1, and is [Bernolli distributed](https://en.wikipedia.org/wiki/Bernoulli_distribution).
# $\def\logi{\frac{1}{1+e^{-wX}}}$
# We also assume given $X$, the probability of getting a 1 is the _logistic function_ $\logi$. I will write a detailed introduction to the rationale of it later, but intuitively we can transfrom $y = \logi$ to $\log{y} + \log{1-y} = wX$, where we map the probability of getting a both answers to a linear transfromation of $X$ by $w$ using $\log$ function.

# %% [markdown]
# #### Maximun Likelihood Estimation(MLE):
#
# Given the sampled data, we can estimate linear parameter $w$ using maximumize likelihood estimation, where we find the most possible $w$ that generates the data.
#
#
# * First we find log-likelihood, which is equivalent to likelihood if we want to maximize it:
#
# $$
# \begin{align*}
#     &\log{P(Y_1, Y_2, \ldots, Y_n\mid X_1, X_2, \ldots, X_n, w)}    \\
#     =& \log{\prod_{i=1}^{n} {P(Y_i \mid X_i, w)}} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i \mid X_i, w)}} \\
#     & \text{(Assume \( Y_i\) is bernolli distrubuted with \( p=\frac{1}{1+e^{-wX}}\) )} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i=1 \mid X_i, w)^{I_{Y_i=1}}P(Y_i=0 \mid X_i, w)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{\log{p^{I_{Y_i=1}}(1-p)^{I_{Y_i=0}}}} \\
#     =& \sum_{i=1}^{n}{{I_{Y_i=1}}\log{p} +{I_{Y_i=0}}\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{p} + (1-Y_i)\log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_i\log{\frac{p}{1-p}} + \log{(1-p)}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i + \log{\frac{e^{-wX_i}}{1+e^{-wX_i}}}} \\
#     =& \sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}} \\
# \end{align*}
# $$
#
# Hence we are finding
# $$
# \max_{w}{\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}}}
# $$

# %% [markdown]
# ### Gradient Descent
#
# From MLE, we have the following optimization problem:
# $$
#    \max_{w}{\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}}}
# $$
#
# We can use gradient ascent to iteratively find the maximum, where we calculate the gradient of the likelihood in each step, and update $w$ by $ w_{t+1} = w_{t} + \nabla_w$
#
# * Calculating the Gradient:
#
# $$
# \begin{align*}
#     & \nabla_w{(\sum_{i=1}^{n}{Y_iwX_i - wX_i - \log{(1+e^{-wX_i})}})} \\
#     =& \sum_{i=1}^{n} Y_iX_i - X_i + \frac{X_ie^{-wX_i}}{1+e^{-wX_i}}\\
# %    =& \sum_{i=1}^{n} Y_iX_i - X_i\frac{1}{1+e^{-wX_i}}\\
#     & \text{(Let}\hat{Y}_i = \frac{1}{1+e^{-wX_i}}) \\
#     =& \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i\\
# \end{align*}
# $$
#
# * Hence we can find the maximum by:
#
# $$
#     w_{t+1} = w_{t} + \alpha \sum_{i=1}^{n} (Y_i-\hat{Y}_i) X_i
# $$
#
# , where $\alpha$ is the learning rate

# %% [markdown]
# ### Numpy implementation:
#
# We first define the logistic function and two ways to calculate the likelihood as Python functions

# %%
import numpy as np
import numpy.random as rnd

def logistic(_x, _w):  
    # _x : numpy 2DArray
    # _w : numpy 1DArray
    # _w.size = _x.shape[1]
    return 1/(1 + np.exp(-_x.dot(_w)))

def log_likelihood(_X, _Y, _w):
    wX = _X.dot(_w)
    return (_Y - 1).dot(wX) - np.sum(np.logaddexp(0, -wX))
    
def log_likelihood2(_Y, _Yhat):
    _p = (1 - _Y)*(1 - _Yhat) + _Y*_Yhat
    return np.sum(np.log(_p))

# %% [markdown]
# and we add a column of 1 to $X$ to simulate $wX + b$ by $w[X:1]$

# %%
add_offset = lambda X: np.hstack((X, np.ones((X.shape[0], 1))))
X_with_offset = add_offset(gm.tr.X)

# %% [markdown]
# * Then we implement gradient ascent on ```w```
#
# Note that we dynamically adjust the learning rate ```lr``` using [backtracking](https://en.wikipedia.org/wiki/Backtracking_line_search) with parameter ```beta``` and ```alpha```.
#
# The for loop will end if maximun iteration is reached or the error converges.

# %%
max_iter = 1000
min_err_change = 0.0001

w = rnd.uniform(-1, 1, X_with_offset.shape[1])

lr = 0.1  # Learning rate
beta = 0.8 # Backtracking
alpha = 0.5 # Backtracking


err0 = None

for _ in range(max_iter):
    pred_lbs = logistic(X_with_offset, w)
    diff_lb = gm.tr.y[:,0] - pred_lbs
    err = np.sum(np.abs(diff_lb))
    
    _lll = log_likelihood(X_with_offset, gm.tr.y[:,0], w)
    # print((lr, err, _lll, _lll2, w))
    if err0:
        if abs(err - err0) < min_err_change:
            print(_)
            break
    err0 = err
    grad = diff_lb.dot(X_with_offset)
    lr = 0.1  # Learning rate
    while log_likelihood(X_with_offset, gm.tr.y[:,0], w+lr*grad) < _lll + lr*alpha*grad.dot(grad):
        lr *= beta
    w += lr*grad

# %% [markdown]
# #### Visualization of the classification results

# %%
def regress(_x, _w):
    _y = logistic(add_offset(_x), _w)
    _Y = np.column_stack((_y, 1 - _y))
    return _Y

gmg.visualize_2D(gm.Classes, gm.class_colors, classifyF=lambda x: regress(x, w), res=80)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="