# %%
import tensorflow as tf
import numpy as np
import toy_data.gaussian_mixtures as gmg
import bokeh

# %%
bokeh.io.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="753f75d4-4604-40e1-9d2c-6afe421552ef">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# ### Multi-class Logistic Regression
#
# * Assumption:
#
# $$
# Y|X \sim \text{Categorical}(p_1, \ldots, p_n = \frac{e^{w_n X}}{\sum_{k=1}^{n}{e^{w_k X}} })
# $$
#
# * Log likelihood:
#
# $$
# \begin{align*}
#     =& \log{\prod_{i=1}^{n} {P(Y_i \mid X_i, w_1, \ldots, w_n)}} \\
#     =& \sum_{i=1}^{n}{\log{P(Y_i \mid X_i, w_1, \ldots, w_n)}} \\
#     & (\text{Assume \( Y_i \) is catigorical distrubuted with } p_1, \ldots, p_n) \\
#     =& \sum_{i=1}^{n}{\log{\prod_{k=1}^{n}{P(Y_i=1 \mid X_i, w_k)^{I_{Y_i=k}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {\log{p_k^{I_{Y_i=k}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {I_{Y_i=k}\log{p_k}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {Y_i\log{\frac{e^{w_n X_i}}{\sum_{k=1}^{n}{e^{w_k X_i}}}}}} \\
#     =& \sum_{i=1}^{n}{\sum_{k=1}^n {Y_i(w_k X_i - \log{\sum_{k=1}^{n}{e^{w_k X_i}}})}} \\
# \end{align*}
# $$
#
# * Gradient of log likelihood
#
# $$
# \begin{align*}
#     &\nabla_W{\sum_{i=1}^{n}{\sum_{k=1}^n {Y_i(w_k X_i - \log{\sum_{k=1}^{n}{e^{w_k X_i}}})}}}\\
#     =& \sum_{i=1}^{n}{Y_i X_i + \hat{Y}_i X_i} \\
#     &(\text{where } \hat{Y}_i = \frac{e^{w_n X_i}}{\sum_{k=1}^{n}{e^{w_k X_i}}})
# \end{align*}
# $$

# %%
Nclass = 4
gm = gmg.GaussianMixture(n_class=Nclass)
gmg.visualize_2D(gm.Classes, gm.class_colors)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="c1188ff6-d61c-4a08-bb11-39a1583ee595"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c1188ff6-d61c-4a08-bb11-39a1583ee595");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c1188ff6-d61c-4a08-bb11-39a1583ee595' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"731bf09d-9b1b-47bc-b523-9e7317c40fe2":{"roots":{"references":[{"attributes":{"fill_color":{"value":"#55B236"},"line_color":{"value":"#55B236"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7bede25c-9fbe-4eef-b702-c13d4b62d811","type":"Circle"},{"attributes":{"fill_color":{"value":"#B23E36"},"line_color":{"value":"#B23E36"},"x":{"field":"x"},"y":{"field":"y"}},"id":"af29060b-a8bf-47cf-a93a-8c89af3f647a","type":"Circle"},{"attributes":{"data_source":{"id":"958e1dd5-91a9-4cfb-a1a6-e2453458ea02","type":"ColumnDataSource"},"glyph":{"id":"b913e864-51db-409c-90c9-180569899ec6","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"55031b7a-8061-448f-8322-8ee1b09174ec","type":"Circle"},"selection_glyph":null},"id":"6b0fb25e-5d92-448b-abf0-8def9cec5129","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[6.033500935785403,6.171963215723737,3.6653057078322777,5.981784418299941,8.652669759687145,4.12594065550897,9.64566764208707,6.499839138154831,4.869963649506248,10.43998185326145,9.471957043174674,7.305289848135898,8.269373397800454,4.871718132361591,7.80726543403286,8.963632788904016,8.390931661732413,9.987196992388032,6.907789384772609,10.425414389563088,7.451610361860412,5.114938004472658,6.751169424268894,6.672176412732634,6.133043829866906,3.875160461434536,7.581460823197061,6.2462789447583535,9.421758579730751,8.973470242931114,8.404308706992303,5.90641457959564,4.220596509087104,7.378268622398076,6.808252807824865,4.978809166903791,7.066018143313796,7.065125461736119,4.898472386290885,4.393055475813556,5.064544095565555,4.878427807507094,0.83077221273102,8.128833864565864,7.409719711578984,